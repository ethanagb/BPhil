# %%
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# # FC 20

# %%
fc20 = pd.read_csv("../../data/proc/FC20.txt", sep='\t',header=0,encoding='cp1252')

# %%
fc20.head()
# Out:
#       Date  RunID  TiltAmp    TiltVel  TiltToLightTime  HRSeg1   FlowSeg1  \
# 0  4/14/14    3.5       60  34.393755         11.94200     168  20.820020
# 1  4/14/14    4.1       20  16.784800          0.00000     192  21.545234
# 2  4/14/14    4.2       60  40.312795          9.61136     180  21.351056
# 3  4/14/14    4.3       60  38.829008          9.46196     180  20.652980
# 4  4/14/14    4.4       20  20.723870          0.00000     180  21.898334
#
#    HRSeg2A  FlowSeg2A  HRSeg2    ...       FlowSeg4  Comments       Checked  \
# 0      180  19.235995     168    ...      21.728479       NaN  _  6/12 - NP
# 1      192  19.673442     204    ...      20.994574       20_  _  6/12 - NP
# 2      204  21.138140     192    ...      20.606849       NaN  _  6/12 - NP
# 3      168  20.160265     168    ...      23.309344       NaN  _  6/12 - NP
# 4      204  18.747556     180    ...      21.648890       20_  _  6/12 - NP
#
# ...

# %%
#Split the data by where they occur in relation to the false cue. 
preTilt = fc20[fc20.TiltPosition == 'Pre']
Tilt = fc20[fc20.TiltPosition == 'Tilt']
postTilt = fc20[fc20.TiltPosition == 'Post']

# %%
#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

# %%
def segmentSummary(segment):
    #print(str(segment) + '\n')
    print("Mean: " + str(np.mean(segment)) + '\n')
    print("STD: " + str(np.std(segment)) + '\n')
    print("Median: " + str(np.median(segment)) + '\n')

segmentList = [preTiltHR_1, preTiltHR_2A, preTiltHR_2, preTiltHR_3, preTiltHR_4, preTiltBF_1, preTiltBF_2A, preTiltBF_2, preTiltBF_3, preTiltBF_4]

for name in segmentList:
    segmentSummary(name)
# Out:
# Mean: 136.64
#
# STD: 24.150991698064857
#
# Median: 132.0
#
# Mean: 138.13333333333333
#
# STD: 23.572488672650188
#
# Median: 132.0
#
# Mean: 138.45333333333335
#
# STD: 24.264263617280665
#
# Median: 132.0
#
# Mean: 152.10666666666665
#
# STD: 25.009637253578028
#
# Median: 156.0
#
# Mean: 146.82666666666665
#
# STD: 27.135400412663103
#
# Median: 144.0
#
# Mean: 40.492415564631116
#
# STD: 19.874820726818655
#
# Median: 40.59945679
#
# Mean: 39.89796389611557
#
# STD: 19.636228329394076
#
# Median: 40.21722412
#
# Mean: 39.170393499635544
#
# STD: 19.15877859750474
#
# Median: 39.6752881
#
# Mean: 40.1583088089511
#
# STD: 21.181889667293717
#
# Median: 40.88456997
#
# Mean: 40.60786013700442
#
# STD: 21.88145995700383
#
# Median: 41.89733887

# %%
#Extract data for the segments. 
#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]

segmentList = [TiltHR_1, TiltHR_2A, TiltHR_2, TiltHR_3, TiltHR_4, TiltBF_1, TiltBF_2A, TiltBF_2, TiltBF_3, TiltBF_4]

for name in segmentList:
    segmentSummary(name)
# Out:
# Mean: 136.42666666666668
#
# STD: 24.972076850398782
#
# Median: 132.0
#
# Mean: 137.06666666666666
#
# STD: 23.032344407135103
#
# Median: 132.0
#
# Mean: 138.05357142857142
#
# STD: 24.053452115516976
#
# Median: nan
#
# Mean: 139.44642857142858
#
# STD: 23.604947758329587
#
# Median: nan
#
# Mean: 138.42857142857142
#
# STD: 26.174453973604237
#
# Median: nan
#
# Mean: 40.43693553451111
#
# STD: 19.745257970957343
#
# Median: 41.47619629
#
# Mean: 40.18762120592444
#
# STD: 19.563043821168822
#
# Median: 40.67434692
#
# Mean: 39.76576655301786
#
# STD: 19.266385857587327
#
# Median: nan
#
# Mean: 39.43278046894642
#
# STD: 19.425658134284692
#
# Median: nan
#
# Mean: 40.1456834319643
#
# STD: 19.80218958795706
#
# Median: nan
# /Users/eagb/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3569: RuntimeWarning: Invalid value encountered in median
#   RuntimeWarning)

# %%
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]

segmentList = [postTiltHR_1, postTiltHR_2A, postTiltHR_2, postTiltHR_3, postTiltHR_4, postTiltBF_1, postTiltBF_2A, postTiltBF_2, postTiltBF_3, postTiltBF_4]

for name in segmentList:
    segmentSummary(name)
# Out:
# Mean: 138.58753709198814
#
# STD: 23.61810825519817
#
# Median: 132.0
#
# Mean: 139.97626112759644
#
# STD: 23.86707813415335
#
# Median: 144.0
#
# Mean: 139.40652818991097
#
# STD: 23.78197866687126
#
# Median: 132.0
#
# Mean: 151.01483679525222
#
# STD: 25.46708621272244
#
# Median: 144.0
#
# Mean: 146.45697329376856
#
# STD: 28.61955641229743
#
# Median: 144.0
#
# Mean: 28.237730824370917
#
# STD: 20.537682933704456
#
# Median: 22.73681397
#
# Mean: 27.667170648557846
#
# STD: 19.913776764265663
#
# Median: 22.54112653
#
# Mean: 27.862605014881314
#
# STD: 20.1823510989457
#
# Median: 23.17486572
#
# Mean: 28.16525165756084
#
# STD: 21.452121248823644
#
# Median: 21.60245549
#
# Mean: 28.391863499985185
#
# STD: 21.796804340723774
#
# Median: 20.60684873

# %%
plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='FlowSeg1', data = fc20, hue='CatName')
plt.title("Tilt Sequence, Blood Flow Segment 1")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_BF1.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='FlowSeg2A', data = fc20, hue='CatName')
plt.title("Tilt Sequence, Blood Flow Segment 2A")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_BF2A.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='FlowSeg2', data = fc20, hue='CatName')
plt.title("Tilt Sequence, Blood Flow Segment 2")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_BF2.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='FlowSeg3', data = fc20, hue='CatName')
plt.title("Tilt Sequence, Blood Flow Segment 3")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_BF3.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='FlowSeg4', data = fc20, hue='CatName')
plt.title("Tilt Sequence, Blood Flow Segment 4")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_BF4.png', dpi=500)
#plt.show()

# %%
plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='HRSeg1', data = fc20, hue='CatName')
plt.title("Tilt Sequence, HR Segment 1")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_HR1_FC20.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='HRSeg2A', data = fc20, hue='CatName')
plt.title("Tilt Sequence, HR Segment 2A")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_HR2A_FC20.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='HRSeg2', data = fc20, hue='CatName')
plt.title("Tilt Sequence, HR Segment 2")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_HR2_FC20.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='HRSeg3', data = fc20, hue='CatName')
plt.title("Tilt Sequence, HR Segment 3")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_HR3_FC20.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='HRSeg4', data = fc20, hue='CatName')
plt.title("Tilt Sequence, HR Segment 4")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_HR4_FC20.png', dpi=500)
#plt.show()

# %%
#are values in each segment overall different?

#HR

print(sp.stats.ttest_ind(preTiltHR_1, TiltHR_1, equal_var=False))
print(sp.stats.ttest_ind(preTiltHR_2A, TiltHR_2A, equal_var=False))
print(sp.stats.ttest_ind(preTiltHR_2, TiltHR_2, equal_var=False))
print(sp.stats.ttest_ind(preTiltHR_3, TiltHR_3, equal_var=False))
print(sp.stats.ttest_ind(preTiltHR_4, TiltHR_4, equal_var=False))
print(sp.stats.ttest_ind(preTiltBF_1, TiltBF_1, equal_var=False))
print(sp.stats.ttest_ind(preTiltBF_2A, TiltBF_2A, equal_var=False))
print(sp.stats.ttest_ind(preTiltBF_2, TiltBF_2, equal_var=False))
print(sp.stats.ttest_ind(preTiltBF_3, TiltBF_3, equal_var=False))
print(sp.stats.ttest_ind(preTiltBF_4, TiltBF_4, equal_var=False))
# Out:
# Ttest_indResult(statistic=-0.32853472910239251, pvalue=0.74260974592471651)
# Ttest_indResult(statistic=-0.43910336725300952, pvalue=0.6607278727100705)
# Ttest_indResult(statistic=-0.32694221575503202, pvalue=0.74381405053735328)
# Ttest_indResult(statistic=1.3696478366424281, pvalue=0.17125456343682841)
# Ttest_indResult(statistic=1.318681163052833, pvalue=0.18772506102389158)
# Ttest_indResult(statistic=0.12045682957239662, pvalue=0.90415728131289097)
# Ttest_indResult(statistic=-0.041798514791803243, pvalue=0.96667173517522076)
# Ttest_indResult(statistic=0.0024893531078261982, pvalue=0.9980145244427816)
# Ttest_indResult(statistic=-0.33412985612592466, pvalue=0.73838582895873439)
# Ttest_indResult(statistic=-0.13071537714805648, pvalue=0.89603959194820348)

# %%
print(sp.stats.ttest_ind(postTiltHR_1, TiltHR_1, equal_var=False))
print(sp.stats.ttest_ind(postTiltHR_2A, TiltHR_2A, equal_var=False))
print(sp.stats.ttest_ind(postTiltHR_2, TiltHR_2, equal_var=False))
print(sp.stats.ttest_ind(postTiltHR_3, TiltHR_3, equal_var=False))
print(sp.stats.ttest_ind(postTiltHR_4, TiltHR_4, equal_var=False))
print(sp.stats.ttest_ind(postTiltBF_1, TiltBF_1, equal_var=False))
print(sp.stats.ttest_ind(postTiltBF_2A, TiltBF_2A, equal_var=False))
print(sp.stats.ttest_ind(postTiltBF_2, TiltBF_2, equal_var=False))
print(sp.stats.ttest_ind(postTiltBF_3, TiltBF_3, equal_var=False))
print(sp.stats.ttest_ind(postTiltBF_4, TiltBF_4, equal_var=False))
# Out:
# Ttest_indResult(statistic=-0.019474991995905921, pvalue=0.98446796784374691)
# Ttest_indResult(statistic=-0.29291551946892541, pvalue=0.76967718561244769)
# Ttest_indResult(statistic=-0.019533710043283203, pvalue=0.98442114469423259)
# Ttest_indResult(statistic=0.31297137400733643, pvalue=0.7543996146527473)
# Ttest_indResult(statistic=-0.24252656725711552, pvalue=0.80844617606703983)
# Ttest_indResult(statistic=-0.13345082993509777, pvalue=0.89387680147058068)
# Ttest_indResult(statistic=-0.12199089100684372, pvalue=0.90294270274252242)
# Ttest_indResult(statistic=-0.1574900990861702, pvalue=0.87490591860886879)
# Ttest_indResult(statistic=-0.2795194091926772, pvalue=0.77993225811701272)
# Ttest_indResult(statistic=-0.24845487094622942, pvalue=0.80385839078789423)

# %% [markdown]
# # FC 60

# %%
fc60 = pd.read_csv("../../data/proc/FC60.txt", sep='\t',header=0,encoding='cp1252')

# %%
#Split the data by where they occur in relation to the false cue. 
preTilt = fc60[fc60.TiltPosition == 'Pre']
Tilt = fc60[fc60.TiltPosition == 'Tilt']
postTilt = fc60[fc60.TiltPosition == 'Post']

# %%
#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

segmentList = [preTiltHR_1, preTiltHR_2A, preTiltHR_2, preTiltHR_3, preTiltHR_4, preTiltBF_1, preTiltBF_2A, preTiltBF_2, preTiltBF_3, preTiltBF_4]

for name in segmentList:
    segmentSummary(name)
# Out:
# Mean: 136.64
#
# STD: 24.150991698064857
#
# Median: 132.0
#
# Mean: 138.13333333333333
#
# STD: 23.572488672650188
#
# Median: 132.0
#
# Mean: 138.45333333333335
#
# STD: 24.264263617280665
#
# Median: 132.0
#
# Mean: 152.10666666666665
#
# STD: 25.009637253578028
#
# Median: 156.0
#
# Mean: 146.82666666666665
#
# STD: 27.135400412663103
#
# Median: 144.0
#
# Mean: 40.492415564631116
#
# STD: 19.874820726818655
#
# Median: 40.59945679
#
# Mean: 39.89796389611557
#
# STD: 19.636228329394076
#
# Median: 40.21722412
#
# Mean: 39.170393499635544
#
# STD: 19.15877859750474
#
# Median: 39.6752881
#
# Mean: 40.1583088089511
#
# STD: 21.181889667293717
#
# Median: 40.88456997
#
# Mean: 40.60786013700442
#
# STD: 21.88145995700383
#
# Median: 41.89733887

# %%
#Extract data for the segments. 
#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]

segmentList = [TiltHR_1, TiltHR_2A, TiltHR_2, TiltHR_3, TiltHR_4, TiltBF_1, TiltBF_2A, TiltBF_2, TiltBF_3, TiltBF_4]

for name in segmentList:
    segmentSummary(name)
# Out:
# Mean: 136.42666666666668
#
# STD: 24.972076850398782
#
# Median: 132.0
#
# Mean: 137.06666666666666
#
# STD: 23.032344407135103
#
# Median: 132.0
#
# Mean: 138.05357142857142
#
# STD: 24.053452115516976
#
# Median: nan
#
# Mean: 139.44642857142858
#
# STD: 23.604947758329587
#
# Median: nan
#
# Mean: 138.42857142857142
#
# STD: 26.174453973604237
#
# Median: nan
#
# Mean: 40.43693553451111
#
# STD: 19.745257970957343
#
# Median: 41.47619629
#
# Mean: 40.18762120592444
#
# STD: 19.563043821168822
#
# Median: 40.67434692
#
# Mean: 39.76576655301786
#
# STD: 19.266385857587327
#
# Median: nan
#
# Mean: 39.43278046894642
#
# STD: 19.425658134284692
#
# Median: nan
#
# Mean: 40.1456834319643
#
# STD: 19.80218958795706
#
# Median: nan
# /Users/eagb/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3569: RuntimeWarning: Invalid value encountered in median
#   RuntimeWarning)

# %%
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]

segmentList = [postTiltHR_1, postTiltHR_2A, postTiltHR_2, postTiltHR_3, postTiltHR_4, postTiltBF_1, postTiltBF_2A, postTiltBF_2, postTiltBF_3, postTiltBF_4]

for name in segmentList:
    segmentSummary(name)
# Out:
# Mean: 136.26666666666668
#
# STD: 25.063829626686253
#
# Median: 132.0
#
# Mean: 135.68
#
# STD: 24.68152345379031
#
# Median: 132.0
#
# Mean: 135.68
#
# STD: 23.62154948346956
#
# Median: 132.0
#
# Mean: 151.89333333333335
#
# STD: 27.23114556695869
#
# Median: 156.0
#
# Mean: 149.22666666666666
#
# STD: 31.326058730002327
#
# Median: 144.0
#
# Mean: 39.397526654711115
#
# STD: 19.40807304465999
#
# Median: 38.43399048
#
# Mean: 38.187437120355554
#
# STD: 18.730153303826
#
# Median: 37.73394982
#
# Mean: 38.67284845455999
#
# STD: 18.852914129836027
#
# Median: 39.03826904
#
# Mean: 39.33975745957332
#
# STD: 21.229993438205483
#
# Median: 41.17262911
#
# Mean: 40.19354125772443
#
# STD: 22.052102145808295
#
# Median: 42.73120117

# %%
boo60 = fc60[fc60.CatName == "Boo"]
maverick60 = fc60[fc60.CatName == "Maverick"]
nitro60 = fc60[fc60.CatName == "Nitro"]
shakespurr60 = fc60[fc60.CatName =="Shakespurr"]
purrcilla60 = fc60[fc60.CatName == "Purrcilla"]
clifford60 = fc60[fc60.CatName == "Clifford"]

boo20 = fc20[fc20.CatName == "Boo"]
maverick20 = fc20[fc20.CatName == "Maverick"]
nitro20 = fc20[fc20.CatName == "Nitro"]
shakespurr20 = fc20[fc20.CatName =="Shakespurr"]
purrcilla20 = fc20[fc20.CatName == "Purrcilla"]
clifford20 = fc20[fc20.CatName == "Clifford"]

# %%
# Out:
# 9.154781205545454
# 190

# %%
preTilt = boo20[boo20.TiltPosition == 'Pre']
Tilt = boo20[boo20.TiltPosition == 'Tilt']
postTilt = boo20[boo20.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
print(np.mean(preTiltBF_1))

f = open('/Users/eagb/Documents/BPhil/analysis/data/proc/individualAnalysisFC20.txt', "w+")
f.write("Boo" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Boo" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Boo" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

preTilt = maverick20[maverick20.TiltPosition == 'Pre']
Tilt = maverick20[maverick20.TiltPosition == 'Tilt']
postTilt = maverick20[maverick20.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
print(np.mean(preTiltBF_1))

#f = open('/Users/eagb/Documents/BPhil/analysis/data/proc/individualAnalysisFC60.txt', "w+")
f.write("Maverick" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Maverick" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Maverick" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

preTilt = nitro20[nitro20.TiltPosition == 'Pre']
Tilt = nitro20[nitro20.TiltPosition == 'Tilt']
postTilt = nitro20[nitro20.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
#print(np.mean(preTiltBF_1))
f.write("Nitro" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Nitro" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Nitro" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

preTilt = shakespurr20[shakespurr20.TiltPosition == 'Pre']
Tilt = shakespurr20[shakespurr20.TiltPosition == 'Tilt']
postTilt = shakespurr20[shakespurr20.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
#print(np.mean(preTiltBF_1))
f.write("Shakespurr" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Shakespurr" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Shakespurr" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

preTilt = purrcilla20[purrcilla20.TiltPosition == 'Pre']
Tilt = purrcilla20[purrcilla20.TiltPosition == 'Tilt']
postTilt = purrcilla20[purrcilla20.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
#print(np.mean(preTiltBF_1))
f.write("Purrcilla" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Purrcilla" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Purrcilla" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

preTilt = clifford20[clifford20.TiltPosition == 'Pre']
Tilt = clifford20[clifford20.TiltPosition == 'Tilt']
postTilt = clifford20[clifford20.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
#print(np.mean(preTiltBF_1))
f.write("Clifford" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Clifford" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Clifford" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

f.close()
# Out:
# 10.299270486123808
# 17.745794640145828

# %%
preTilt = boo60[boo60.TiltPosition == 'Pre']
Tilt = boo60[boo60.TiltPosition == 'Tilt']
postTilt = boo60[boo60.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
print(np.mean(preTiltBF_1))

f = open('/Users/eagb/Documents/BPhil/analysis/data/proc/individualAnalysisFC60.txt', "w+")
f.write("Boo" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Boo" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Boo" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

preTilt = maverick60[maverick60.TiltPosition == 'Pre']
Tilt = maverick60[maverick60.TiltPosition == 'Tilt']
postTilt = maverick60[maverick60.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
print(np.mean(preTiltBF_1))

f = open('/Users/eagb/Documents/BPhil/analysis/data/proc/individualAnalysisFC60.txt', "w+")
f.write("Maverick" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Maverick" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Maverick" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

preTilt = nitro60[nitro60.TiltPosition == 'Pre']
Tilt = nitro60[nitro60.TiltPosition == 'Tilt']
postTilt = nitro60[nitro60.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
#print(np.mean(preTiltBF_1))
f.write("Nitro" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Nitro" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Nitro" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

preTilt = shakespurr60[shakespurr60.TiltPosition == 'Pre']
Tilt = shakespurr60[shakespurr60.TiltPosition == 'Tilt']
postTilt = shakespurr60[shakespurr60.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
#print(np.mean(preTiltBF_1))
f.write("Shakespurr" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Shakespurr" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Shakespurr" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

preTilt = purrcilla60[purrcilla60.TiltPosition == 'Pre']
Tilt = purrcilla60[purrcilla60.TiltPosition == 'Tilt']
postTilt = purrcilla60[purrcilla60.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
#print(np.mean(preTiltBF_1))
f.write("Purrcilla" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Purrcilla" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Purrcilla" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

preTilt = clifford60[clifford60.TiltPosition == 'Pre']
Tilt = clifford60[clifford60.TiltPosition == 'Tilt']
postTilt = clifford60[clifford60.TiltPosition == 'Post']

#Extract data for the segments. 
#HR Segments:
preTiltHR_1 = preTilt["HRSeg1"]
preTiltHR_2A = preTilt["HRSeg2A"]
preTiltHR_2 = preTilt["HRSeg2"]
preTiltHR_3 = preTilt["HRSeg3"]
preTiltHR_4 = preTilt["HRSeg4"]

#Flow segments:
preTiltBF_1 = preTilt["FlowSeg1"]
preTiltBF_2A = preTilt["FlowSeg2A"]
preTiltBF_2 = preTilt["FlowSeg2"]
preTiltBF_3 = preTilt["FlowSeg3"]
preTiltBF_4 = preTilt["FlowSeg4"]

#HR Segments:
TiltHR_1 = Tilt["HRSeg1"]
TiltHR_2A = Tilt["HRSeg2A"]
TiltHR_2 = Tilt["HRSeg2"]
TiltHR_3 = Tilt["HRSeg3"]
TiltHR_4 = Tilt["HRSeg4"]

#Flow segments:
TiltBF_1 = Tilt["FlowSeg1"]
TiltBF_2A = Tilt["FlowSeg2A"]
TiltBF_2 = Tilt["FlowSeg2"]
TiltBF_3 = Tilt["FlowSeg3"]
TiltBF_4 = Tilt["FlowSeg4"]
#Extract data for the segments. 
#HR Segments:
postTiltHR_1 = postTilt["HRSeg1"]
postTiltHR_2A = postTilt["HRSeg2A"]
postTiltHR_2 = postTilt["HRSeg2"]
postTiltHR_3 = postTilt["HRSeg3"]
postTiltHR_4 = postTilt["HRSeg4"]

#Flow segments:
postTiltBF_1 = postTilt["FlowSeg1"]
postTiltBF_2 = postTilt["FlowSeg2"]
postTiltBF_2A = postTilt["FlowSeg2A"]
postTiltBF_3 = postTilt["FlowSeg3"]
postTiltBF_4 = postTilt["FlowSeg4"]
#print(np.mean(preTiltBF_1))
f.write("Clifford" + "\t" + str(np.mean(preTiltBF_1)) + "\t" + str(np.mean(preTiltBF_2A))+ "\t" + str(np.mean(preTiltBF_2)) + "\t" + str(np.mean(preTiltBF_3)) + "\t" + str(np.mean(preTiltBF_4)) + "\t" + str(np.mean(preTiltHR_1)) + "\t" + str(np.mean(preTiltHR_2A)) + "\t" + str(np.mean(preTiltHR_2)) + "\t" + str(np.mean(preTiltHR_3)) + "\t" + str(np.mean(preTiltHR_4)) + "\n")
f.write("Clifford" + "\t" + str(np.mean(TiltBF_1)) + "\t" + str(np.mean(TiltBF_2A))+ "\t" + str(np.mean(TiltBF_2)) + "\t" + str(np.mean(TiltBF_3)) + "\t" + str(np.mean(TiltBF_4)) + "\t" + str(np.mean(TiltHR_1)) + "\t" + str(np.mean(TiltHR_2A)) + "\t" + str(np.mean(TiltHR_2)) + "\t" + str(np.mean(TiltHR_3)) + "\t" + str(np.mean(TiltHR_4)) + "\n")
f.write("Clifford" + "\t" + str(np.mean(postTiltBF_1)) + "\t" + str(np.mean(postTiltBF_2A))+ "\t" + str(np.mean(postTiltBF_2)) + "\t" + str(np.mean(postTiltBF_3)) + "\t" + str(np.mean(postTiltBF_4)) + "\t" + str(np.mean(postTiltHR_1)) + "\t" + str(np.mean(postTiltHR_2A)) + "\t" + str(np.mean(postTiltHR_2)) + "\t" + str(np.mean(postTiltHR_3)) + "\t" + str(np.mean(postTiltHR_4)) + "\n")

f.close()
# Out:
# nan
# 9.154781205545454

# %%
plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='FlowSeg1', data = fc60, hue='CatName')
plt.title("Tilt Sequence, Blood Flow Segment 1")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_BF1_FC60.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='FlowSeg2A', data = fc60, hue='CatName')
plt.title("Tilt Sequence, Blood Flow Segment 2A")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_BF2A_FC60.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='FlowSeg2', data = fc60, hue='CatName')
plt.title("Tilt Sequence, Blood Flow Segment 2")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_BF2_FC60.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='FlowSeg3', data = fc60, hue='CatName')
plt.title("Tilt Sequence, Blood Flow Segment 3")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_BF3_FC60.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='FlowSeg4', data = fc60, hue='CatName')
plt.title("Tilt Sequence, Blood Flow Segment 4")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_BF_FC60.png', dpi=500)
#plt.show()

# %%
plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='HRSeg1', data = fc20, hue='CatName')
plt.title("Tilt Sequence, HR Segment 1")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_HR1_FC20.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='HRSeg2A', data = fc60, hue='CatName')
plt.title("Tilt Sequence, HR Segment 2A")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_HR2A_FC60.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='HRSeg2', data = fc60, hue='CatName')
plt.title("Tilt Sequence, HR Segment 2")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_HR2_FC60.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='HRSeg3', data = fc60, hue='CatName')
plt.title("Tilt Sequence, HR Segment 3")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_HR3_FC60.png', dpi=500)
#plt.show()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='NumTiltPos',y='HRSeg4', data = fc60, hue='CatName')
plt.title("Tilt Sequence, HR Segment 4")
plt.xlabel('Tilt Orientation')
plt.ylabel("Blood Flow")
#plt.xlim((-.5,5.5))
#plt.ylim((-10,10))
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/TiltSeq_HR4_FC60.png', dpi=500)
#plt.show()
# Out:
# /Users/eagb/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
#are values in each segment overall different?

#HR

print(sp.stats.ttest_ind(preTiltHR_1, TiltHR_1, equal_var=False))
print(sp.stats.ttest_ind(preTiltHR_2A, TiltHR_2A, equal_var=False))
print(sp.stats.ttest_ind(preTiltHR_2.dropna(), TiltHR_2.dropna(), equal_var=False))
print(sp.stats.ttest_ind(preTiltHR_3.dropna(), TiltHR_3.dropna(), equal_var=False))
print(sp.stats.ttest_ind(preTiltHR_4.dropna(), TiltHR_4.dropna(), equal_var=False))
print(sp.stats.ttest_ind(preTiltBF_1, TiltBF_1, equal_var=False))
print(sp.stats.ttest_ind(preTiltBF_2A, TiltBF_2A, equal_var=False))
print(sp.stats.ttest_ind(preTiltBF_2.dropna(), TiltBF_2.dropna(), equal_var=False))
print(sp.stats.ttest_ind(preTiltBF_3.dropna(), TiltBF_3.dropna(), equal_var=False))
print(sp.stats.ttest_ind(preTiltBF_4.dropna(), TiltBF_4.dropna(), equal_var=False))
# Out:
# Ttest_indResult(statistic=0.091907632469802214, pvalue=0.92681255504377202)
# Ttest_indResult(statistic=0.48440387358133641, pvalue=0.628336125962629)
# Ttest_indResult(statistic=0.17492335221148334, pvalue=0.86121906506243051)
# Ttest_indResult(statistic=5.5039540446799489, pvalue=6.2774832437299067e-08)
# Ttest_indResult(statistic=3.3302200954275838, pvalue=0.00093975481034912288)
# Ttest_indResult(statistic=0.029638624134229054, pvalue=0.97636846043082515)
# Ttest_indResult(statistic=-0.15640287781207662, pvalue=0.87578592414963996)
# Ttest_indResult(statistic=-0.32758325256188653, pvalue=0.74338016791151218)
# Ttest_indResult(statistic=0.37743002827446409, pvalue=0.70603438917711436)
# Ttest_indResult(statistic=0.23415514200384024, pvalue=0.81497271461590071)

# %%
print(sp.stats.ttest_ind(postTiltHR_1, TiltHR_1, equal_var=False))
print(sp.stats.ttest_ind(postTiltHR_2A, TiltHR_2A, equal_var=False))
print(sp.stats.ttest_ind(postTiltHR_2.dropna(), TiltHR_2.dropna(), equal_var=False))
print(sp.stats.ttest_ind(postTiltHR_3.dropna(), TiltHR_3.dropna(), equal_var=False))
print(sp.stats.ttest_ind(postTiltHR_4.dropna(), TiltHR_4.dropna(), equal_var=False))
print(sp.stats.ttest_ind(postTiltBF_1, TiltBF_1, equal_var=False))
print(sp.stats.ttest_ind(postTiltBF_2A, TiltBF_2A, equal_var=False))
print(sp.stats.ttest_ind(postTiltBF_2.dropna(), TiltBF_2.dropna(), equal_var=False))
print(sp.stats.ttest_ind(postTiltBF_3.dropna(), TiltBF_3.dropna(), equal_var=False))
print(sp.stats.ttest_ind(postTiltBF_4.dropna(), TiltBF_4.dropna(), equal_var=False))
# Out:
# Ttest_indResult(statistic=-0.067682514873713975, pvalue=0.94606856472546785)
# Ttest_indResult(statistic=-0.61476225634887061, pvalue=0.53902533196424929)
# Ttest_indResult(statistic=-1.0525376563394686, pvalue=0.29312186710365867)
# Ttest_indResult(statistic=5.1642679013909438, pvalue=3.6689010396357576e-07)
# Ttest_indResult(statistic=3.9552910352966077, pvalue=8.9259963920608636e-05)
# Ttest_indResult(statistic=-0.56187616497779913, pvalue=0.5744814651831498)
# Ttest_indResult(statistic=-1.1053113861464956, pvalue=0.26961904180359625)
# Ttest_indResult(statistic=-0.60612094605166911, pvalue=0.54474231884195301)
# Ttest_indResult(statistic=-0.04833234716197652, pvalue=0.96147311522120105)
# Ttest_indResult(statistic=0.024142994872020849, pvalue=0.98074943586269436)

# %% [markdown]
# # Segments Over Day

# %%
df = pd.read_csv("../../data/proc/allcats_cleaned.txt", sep = '\t', header=0,error_bad_lines=False)
df.head()
# Out:
#       Date  RunID  TiltAmp    TiltVel  TiltToLightTime  HRSeg1   FlowSeg1  \
# 0  4/14/14    1.2       60  33.822527         10.60736     192  15.846680
# 1  4/14/14    1.3       60  38.685711         10.18904     168  16.591424
# 2  4/14/14    1.4       60  38.426960         10.08944     204  18.848599
# 3  4/14/14    1.5       60  41.588288         10.52768     180  19.250943
# 4  4/14/14    2.1       60  42.361841         10.05956     168  18.906974
#
#    HRSeg2A  FlowSeg2A  HRSeg2   ...     FlowSeg3  HRSeg4   FlowSeg4  Comments  \
# 0      168  18.619668   168.0   ...    17.088212   192.0  18.424471       NaN
# 1      192  18.583448   192.0   ...    17.185249   180.0  18.166914       NaN
# 2      180  18.384433   180.0   ...    17.166065   192.0  17.904955       NaN
# 3      192  17.675648   192.0   ...    18.290926   216.0  17.723181       NaN
# 4      216  19.913778   192.0   ...    17.002022   192.0  19.741140       NaN
#
# ...

# %%
boo = df[df.CatName == "Boo"]
shakespurr = df[df.CatName == "Shakespurr"]
purrcilla = df[df.CatName == "Purrcilla"]
nitro = df[df.CatName == "Nitro"]
maverick = df[df.CatName == "Maverick"]
clifford = df[df.CatName == "Clifford"]

trial6 = boo[boo.RunID >= 6]
trial1 = boo[boo.RunID < 2]

print(np.mean(trial6['HRSeg1']), np.mean(trial1['HRSeg1']))
print(np.mean(trial6['HRSeg2A']), np.mean(trial1['HRSeg2A']))
print(np.mean(trial6['HRSeg2']), np.mean(trial1['HRSeg2']))
print(np.mean(trial6['HRSeg3']), np.mean(trial1['HRSeg3']))
print(np.mean(trial6['HRSeg4']), np.mean(trial1['HRSeg4']))
print(np.mean(trial6['FlowSeg1']), np.mean(trial1['FlowSeg1']))
print(np.mean(trial6['FlowSeg2A']), np.mean(trial1['FlowSeg2A']))
print(np.mean(trial6['FlowSeg2']), np.mean(trial1['FlowSeg2']))
print(np.mean(trial6['FlowSeg3']), np.mean(trial1['FlowSeg3']))
print(np.mean(trial6['FlowSeg4']), np.mean(trial1['FlowSeg4']))


print(sp.stats.ttest_ind(trial6['HRSeg1'], trial1['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2A'], trial1['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2'], trial1['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg3'], trial1['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg4'], trial1['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg1'], trial1['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2A'], trial1['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2'], trial1['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg3'], trial1['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg4'], trial1['FlowSeg4'], equal_var=False))
# Out:
# 150.3021582733813 156.61992619926198
# 151.25179856115108 156.39852398523985
# 153.41007194244605 157.81549815498155
# 171.36690647482015 173.80073800738006
# 177.23741007194243 174.02214022140222
# 10.424645850187051 11.979307387693714
# 10.245809850733819 11.834561137874537
# 10.291960361007195 11.855250673188195
# 9.838227827093522 11.652206252387453
# 9.860212347784177 11.658438021512904
# Ttest_indResult(statistic=-2.9466467772366833, pvalue=0.0034704582674994133)
# Ttest_indResult(statistic=-2.5244256340579234, pvalue=0.012066848611971394)
# Ttest_indResult(statistic=-2.1617327118580225, pvalue=0.031412033335845212)
# Ttest_indResult(statistic=-1.1182529258549807, pvalue=0.26425468051622986)
# Ttest_indResult(statistic=1.0724844171215233, pvalue=0.28429309992572793)
# Ttest_indResult(statistic=-2.0679171905999056, pvalue=0.039722660872609637)
# Ttest_indResult(statistic=-2.1743847571268211, pvalue=0.03066948074299649)
# ...

# %% [markdown]
# Day of Week - Stats

# %%
mon = boo[boo.DayOfWeek == 0]
fri = boo[boo.DayOfWeek == 4]

print(np.mean(fri['HRSeg1']), np.mean(mon['HRSeg1']))
print(np.mean(fri['HRSeg2A']), np.mean(mon['HRSeg2A']))
print(np.mean(fri['HRSeg2']), np.mean(mon['HRSeg2']))
print(np.mean(fri['HRSeg3']), np.mean(mon['HRSeg3']))
print(np.mean(fri['HRSeg4']), np.mean(mon['HRSeg4']))
print(np.mean(fri['FlowSeg1']), np.mean(mon['FlowSeg1']))
print(np.mean(fri['FlowSeg2A']), np.mean(mon['FlowSeg2A']))
print(np.mean(fri['FlowSeg2']), np.mean(mon['FlowSeg2']))
print(np.mean(fri['FlowSeg3']), np.mean(mon['FlowSeg3']))
print(np.mean(fri['FlowSeg4']), np.mean(mon['FlowSeg4']))

print(sp.stats.ttest_ind(fri['HRSeg1'], mon['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2A'], mon['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2'], mon['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg3'], mon['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg4'], mon['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg1'], mon['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2A'], mon['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2'], mon['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg3'], mon['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg4'], mon['FlowSeg4'], equal_var=False))
# Out:
# 146.03305785123968 150.41860465116278
# 147.5206611570248 151.69435215946845
# 148.46280991735537 153.72757475083057
# 162.099173553719 169.71428571428572
# 161.40495867768595 167.48172757475083
# 13.66491064298348 10.643491325976743
# 13.494778618322313 10.331645428770761
# 13.512736958991733 10.391030742707638
# 13.20999371397107 10.089458866966776
# 13.08111179680165 10.26921385451494
# Ttest_indResult(statistic=-2.1714439134376402, pvalue=0.030361045308426926)
# Ttest_indResult(statistic=-2.097174095979518, pvalue=0.036484340614561378)
# Ttest_indResult(statistic=-2.7234078146635117, pvalue=0.0066924771359363746)
# Ttest_indResult(statistic=-3.4044884065917307, pvalue=0.00071913248679326709)
# Ttest_indResult(statistic=-2.2409250259638469, pvalue=0.025501896693742056)
# Ttest_indResult(statistic=5.267781496539369, pvalue=2.1240025964538096e-07)
# Ttest_indResult(statistic=5.7245699588723129, pvalue=1.9082522567323761e-08)
# ...

# %%
trial6 = maverick[maverick.RunID >= 6]
trial1 = maverick[maverick.RunID < 2]
print(np.mean(trial6['HRSeg1']), np.mean(trial1['HRSeg1']))
print(np.mean(trial6['HRSeg2A']), np.mean(trial1['HRSeg2A']))
print(np.mean(trial6['HRSeg2']), np.mean(trial1['HRSeg2']))
print(np.mean(trial6['HRSeg3']), np.mean(trial1['HRSeg3']))
print(np.mean(trial6['HRSeg4']), np.mean(trial1['HRSeg4']))
print(np.mean(trial6['FlowSeg1']), np.mean(trial1['FlowSeg1']))
print(np.mean(trial6['FlowSeg2A']), np.mean(trial1['FlowSeg2A']))
print(np.mean(trial6['FlowSeg2']), np.mean(trial1['FlowSeg2']))
print(np.mean(trial6['FlowSeg3']), np.mean(trial1['FlowSeg3']))
print(np.mean(trial6['FlowSeg4']), np.mean(trial1['FlowSeg4']))

print(sp.stats.ttest_ind(trial6['HRSeg1'], trial1['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2A'], trial1['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2'], trial1['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg3'], trial1['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg4'], trial1['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg1'], trial1['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2A'], trial1['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2'], trial1['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg3'], trial1['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg4'], trial1['FlowSeg4'], equal_var=False))
# Out:
# 135.88888888888889 152.69158878504672
# 135.61111111111111 152.57943925233644
# 134.55555555555554 153.0841121495327
# 146.88888888888889 167.55140186915887
# 140.33333333333334 160.0373831775701
# 20.686960606902772 23.44877839334111
# 19.981820214388883 22.97254850518225
# 19.65742869029166 22.76862595699999
# 17.91060737779168 21.754729979191584
# 18.70038421791667 22.645815503654216
# Ttest_indResult(statistic=-7.7929965482547807, pvalue=5.6170631833522507e-14)
# Ttest_indResult(statistic=-7.8409643374186384, pvalue=4.7521672944270338e-14)
# Ttest_indResult(statistic=-8.3671162888857147, pvalue=1.1623039756695031e-15)
# Ttest_indResult(statistic=-9.1808973205141537, pvalue=2.0470995089075033e-18)
# Ttest_indResult(statistic=-10.054684442464351, pvalue=1.7261500502758351e-21)
# Ttest_indResult(statistic=-3.334009878676242, pvalue=0.00093414869654048392)
# Ttest_indResult(statistic=-3.7600823719258778, pvalue=0.00019488381198756025)
# ...

# %%
mon = maverick[maverick.DayOfWeek == 0]
fri = maverick[maverick.DayOfWeek == 4]

print(np.mean(fri['HRSeg1']), np.mean(mon['HRSeg1']))
print(np.mean(fri['HRSeg2A']), np.mean(mon['HRSeg2A']))
print(np.mean(fri['HRSeg2']), np.mean(mon['HRSeg2']))
print(np.mean(fri['HRSeg3']), np.mean(mon['HRSeg3']))
print(np.mean(fri['HRSeg4']), np.mean(mon['HRSeg4']))
print(np.mean(fri['FlowSeg1']), np.mean(mon['FlowSeg1']))
print(np.mean(fri['FlowSeg2A']), np.mean(mon['FlowSeg2A']))
print(np.mean(fri['FlowSeg2']), np.mean(mon['FlowSeg2']))
print(np.mean(fri['FlowSeg3']), np.mean(mon['FlowSeg3']))
print(np.mean(fri['FlowSeg4']), np.mean(mon['FlowSeg4']))

print(sp.stats.ttest_ind(fri['HRSeg1'], mon['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2A'], mon['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2'], mon['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg3'], mon['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg4'], mon['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg1'], mon['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2A'], mon['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2'], mon['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg3'], mon['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg4'], mon['FlowSeg4'], equal_var=False))
# Out:
# 146.2202643171806 147.8450704225352
# 145.26872246696036 148.43661971830986
# 146.37885462555067 148.43661971830986
# 159.5418502202643 160.85915492957747
# 153.7797356828194 152.95774647887325
# 20.250316184400866 21.36688883875706
# 20.04568817906167 20.56791877255632
# 19.815597015603522 20.291804524764085
# 18.169319194911903 18.862966501327474
# 19.051556445876667 20.082753606278178
# Ttest_indResult(statistic=-0.93098411702151462, pvalue=0.35260544255802251)
# Ttest_indResult(statistic=-1.9714784845367919, pvalue=0.049533610296546342)
# Ttest_indResult(statistic=-1.1888085782870168, pvalue=0.23542687276065727)
# Ttest_indResult(statistic=-0.78145837173707111, pvalue=0.43512788137493608)
# Ttest_indResult(statistic=0.43407170740074669, pvalue=0.66454319384706917)
# Ttest_indResult(statistic=-1.383521071600899, pvalue=0.16715464912636033)
# Ttest_indResult(statistic=-0.66967789147090928, pvalue=0.50339222588166221)
# ...

# %%
trial6 = clifford[clifford.RunID >= 6]
trial1 = clifford[clifford.RunID < 2]
print(np.mean(trial6['HRSeg1']), np.mean(trial1['HRSeg1']))
print(np.mean(trial6['HRSeg2A']), np.mean(trial1['HRSeg2A']))
print(np.mean(trial6['HRSeg2']), np.mean(trial1['HRSeg2']))
print(np.mean(trial6['HRSeg3']), np.mean(trial1['HRSeg3']))
print(np.mean(trial6['HRSeg4']), np.mean(trial1['HRSeg4']))
print(np.mean(trial6['FlowSeg1']), np.mean(trial1['FlowSeg1']))
print(np.mean(trial6['FlowSeg2A']), np.mean(trial1['FlowSeg2A']))
print(np.mean(trial6['FlowSeg2']), np.mean(trial1['FlowSeg2']))
print(np.mean(trial6['FlowSeg3']), np.mean(trial1['FlowSeg3']))
print(np.mean(trial6['FlowSeg4']), np.mean(trial1['FlowSeg4']))

print(sp.stats.ttest_ind(trial6['HRSeg1'], trial1['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2A'], trial1['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2'], trial1['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg3'], trial1['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg4'], trial1['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg1'], trial1['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2A'], trial1['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2'], trial1['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg3'], trial1['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg4'], trial1['FlowSeg4'], equal_var=False))
# Out:
# 120.43438914027149 125.55186721991701
# 120.76018099547511 125.35269709543569
# 120.9502262443439 125.52697095435684
# 134.2262443438914 138.97095435684648
# 131.40271493212668 131.80082987551867
# 56.45965182814475 49.70822798437759
# 55.14612481522619 48.82267418653528
# 54.37408178156105 48.09056883147302
# 56.661273351923114 51.823887868838185
# 58.143082001651585 52.13289280726141
# Ttest_indResult(statistic=-6.0118704315398341, pvalue=2.6443376817621131e-09)
# Ttest_indResult(statistic=-5.7297596098928354, pvalue=1.3624191263076605e-08)
# Ttest_indResult(statistic=-5.7696238806544811, pvalue=1.0850337225306849e-08)
# Ttest_indResult(statistic=-5.143817663418857, pvalue=3.2894588115767638e-07)
# Ttest_indResult(statistic=-0.37806715692767479, pvalue=0.70546991960152727)
# Ttest_indResult(statistic=9.5792072240665238, pvalue=9.7613063220940601e-21)
# Ttest_indResult(statistic=9.0632325331404768, pvalue=8.233737016246854e-19)
# ...

# %%
mon = clifford[clifford.DayOfWeek == 0]
fri = clifford[clifford.DayOfWeek == 4]

print(np.mean(fri['HRSeg1']), np.mean(mon['HRSeg1']))
print(np.mean(fri['HRSeg2A']), np.mean(mon['HRSeg2A']))
print(np.mean(fri['HRSeg2']), np.mean(mon['HRSeg2']))
print(np.mean(fri['HRSeg3']), np.mean(mon['HRSeg3']))
print(np.mean(fri['HRSeg4']), np.mean(mon['HRSeg4']))
print(np.mean(fri['FlowSeg1']), np.mean(mon['FlowSeg1']))
print(np.mean(fri['FlowSeg2A']), np.mean(mon['FlowSeg2A']))
print(np.mean(fri['FlowSeg2']), np.mean(mon['FlowSeg2']))
print(np.mean(fri['FlowSeg3']), np.mean(mon['FlowSeg3']))
print(np.mean(fri['FlowSeg4']), np.mean(mon['FlowSeg4']))

print(sp.stats.ttest_ind(fri['HRSeg1'], mon['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2A'], mon['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2'], mon['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg3'], mon['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg4'], mon['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg1'], mon['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2A'], mon['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2'], mon['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg3'], mon['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg4'], mon['FlowSeg4'], equal_var=False))
# Out:
# 119.4113924050633 124.10309278350516
# 120.07594936708861 125.27835051546391
# 120.15189873417721 125.54639175257732
# 133.74683544303798 139.05154639175257
# 127.48101265822785 132.9278350515464
# 52.57428104047466 56.38108159804121
# 51.67617281094939 55.532912001855664
# 50.95106383814873 54.762358455859044
# 54.00180822159807 58.43289373661507
# 54.89049079351263 59.328328379089385
# Ttest_indResult(statistic=-6.8691959837434249, pvalue=1.0561961812207525e-11)
# Ttest_indResult(statistic=-7.5511619999583903, pvalue=8.8182304607507537e-14)
# Ttest_indResult(statistic=-7.7615713810065605, pvalue=1.8329921523264566e-14)
# Ttest_indResult(statistic=-6.5043872267053722, pvalue=1.1507603371130318e-10)
# Ttest_indResult(statistic=-5.8486861938509556, pvalue=6.6064125152045132e-09)
# Ttest_indResult(statistic=-6.5035468011962028, pvalue=1.1530877396006571e-10)
# Ttest_indResult(statistic=-6.7279789106544374, pvalue=2.6641758916989423e-11)
# ...

# %%
trial6 = shakespurr[shakespurr.RunID >= 6]
trial1 = shakespurr[shakespurr.RunID < 2]
print(np.mean(trial6['HRSeg1']), np.mean(trial1['HRSeg1']))
print(np.mean(trial6['HRSeg2A']), np.mean(trial1['HRSeg2A']))
print(np.mean(trial6['HRSeg2']), np.mean(trial1['HRSeg2']))
print(np.mean(trial6['HRSeg3']), np.mean(trial1['HRSeg3']))
print(np.mean(trial6['HRSeg4']), np.mean(trial1['HRSeg4']))
print(np.mean(trial6['FlowSeg1']), np.mean(trial1['FlowSeg1']))
print(np.mean(trial6['FlowSeg2A']), np.mean(trial1['FlowSeg2A']))
print(np.mean(trial6['FlowSeg2']), np.mean(trial1['FlowSeg2']))
print(np.mean(trial6['FlowSeg3']), np.mean(trial1['FlowSeg3']))
print(np.mean(trial6['FlowSeg4']), np.mean(trial1['FlowSeg4']))

print(sp.stats.ttest_ind(trial6['HRSeg1'], trial1['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2A'], trial1['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2'], trial1['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg3'], trial1['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg4'], trial1['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg1'], trial1['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2A'], trial1['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2'], trial1['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg3'], trial1['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg4'], trial1['FlowSeg4'], equal_var=False))
# Out:
# 159.2842105263158 169.11111111111111
# 158.90526315789472 168.88888888888889
# 157.38947368421051 169.11111111111111
# 166.10526315789474 176.22222222222223
# 171.41052631578947 176.55555555555554
# 26.124826841610528 27.583976185092588
# 25.67393446271579 27.501078580851853
# 25.394647664252634 27.088262073333322
# 24.254941189810534 26.620793003055557
# 25.377410384515784 27.586118073981478
# Ttest_indResult(statistic=-6.64047968539594, pvalue=3.2427037101644631e-10)
# Ttest_indResult(statistic=-7.094856045094736, pvalue=2.1916504244302971e-11)
# Ttest_indResult(statistic=-7.7236177526605134, pvalue=6.0386742999029628e-13)
# Ttest_indResult(statistic=-6.8339404567467286, pvalue=1.0214020567753683e-10)
# Ttest_indResult(statistic=-2.8823718119764044, pvalue=0.0044194274956995822)
# Ttest_indResult(statistic=-1.2842728275488577, pvalue=0.20061421648616354)
# Ttest_indResult(statistic=-1.6427935392373418, pvalue=0.10205297972830195)
# ...

# %%
mon = shakespurr[shakespurr.DayOfWeek == 0]
fri = shakespurr[shakespurr.DayOfWeek == 4]

print(np.mean(fri['HRSeg1']), np.mean(mon['HRSeg1']))
print(np.mean(fri['HRSeg2A']), np.mean(mon['HRSeg2A']))
print(np.mean(fri['HRSeg2']), np.mean(mon['HRSeg2']))
print(np.mean(fri['HRSeg3']), np.mean(mon['HRSeg3']))
print(np.mean(fri['HRSeg4']), np.mean(mon['HRSeg4']))
print(np.mean(fri['FlowSeg1']), np.mean(mon['FlowSeg1']))
print(np.mean(fri['FlowSeg2A']), np.mean(mon['FlowSeg2A']))
print(np.mean(fri['FlowSeg2']), np.mean(mon['FlowSeg2']))
print(np.mean(fri['FlowSeg3']), np.mean(mon['FlowSeg3']))
print(np.mean(fri['FlowSeg4']), np.mean(mon['FlowSeg4']))

print(sp.stats.ttest_ind(fri['HRSeg1'], mon['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2A'], mon['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2'], mon['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg3'], mon['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg4'], mon['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg1'], mon['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2A'], mon['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2'], mon['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg3'], mon['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg4'], mon['FlowSeg4'], equal_var=False))
# Out:
# 159.82417582417582 161.23636363636365
# 160.21978021978023 158.94545454545454
# 159.2967032967033 161.6727272727273
# 165.8901098901099 167.8909090909091
# 167.6043956043956 172.25454545454545
# 24.74716253620879 28.71046752918182
# 24.589859177252762 28.210530506909084
# 24.392585545846142 28.060578733909086
# 23.311458901362645 26.55020981154546
# 24.36320978336263 26.97334965518182
# Ttest_indResult(statistic=-1.069703752706807, pvalue=0.28604905258423047)
# Ttest_indResult(statistic=1.0009585803378471, pvalue=0.31806304424060688)
# Ttest_indResult(statistic=-2.0348041076646006, pvalue=0.043218762856050467)
# Ttest_indResult(statistic=-1.3979256708524928, pvalue=0.16372496965028047)
# Ttest_indResult(statistic=-3.4698175492956391, pvalue=0.00064215744856798622)
# Ttest_indResult(statistic=-2.9089688575417587, pvalue=0.0043962426139373947)
# Ttest_indResult(statistic=-2.6872185384031604, pvalue=0.0084035910281933905)
# ...

# %%
trial6 = purrcilla[purrcilla.RunID >= 6]
trial1 = purrcilla[purrcilla.RunID < 2]
print(np.mean(trial6['HRSeg1']), np.mean(trial1['HRSeg1']))
print(np.mean(trial6['HRSeg2A']), np.mean(trial1['HRSeg2A']))
print(np.mean(trial6['HRSeg2']), np.mean(trial1['HRSeg2']))
print(np.mean(trial6['HRSeg3']), np.mean(trial1['HRSeg3']))
print(np.mean(trial6['HRSeg4']), np.mean(trial1['HRSeg4']))
print(np.mean(trial6['FlowSeg1']), np.mean(trial1['FlowSeg1']))
print(np.mean(trial6['FlowSeg2A']), np.mean(trial1['FlowSeg2A']))
print(np.mean(trial6['FlowSeg2']), np.mean(trial1['FlowSeg2']))
print(np.mean(trial6['FlowSeg3']), np.mean(trial1['FlowSeg3']))
print(np.mean(trial6['FlowSeg4']), np.mean(trial1['FlowSeg4']))

print(sp.stats.ttest_ind(trial6['HRSeg1'], trial1['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2A'], trial1['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2'], trial1['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg3'], trial1['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg4'], trial1['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg1'], trial1['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2A'], trial1['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2'], trial1['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg3'], trial1['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg4'], trial1['FlowSeg4'], equal_var=False))
# Out:
# 158.2921348314607 166.62857142857143
# 158.86516853932585 167.15844155844155
# 160.2134831460674 168.87272727272727
# 168.40449438202248 176.63376623376624
# 170.52808988764045 177.16363636363636
# 22.98412665064606 27.932168599532456
# 22.82940844955057 27.5259540538182
# 22.733305540224734 27.674040342259765
# 21.46382473719101 26.37011676945457
# 20.74420289763764 25.049002426283117
# Ttest_indResult(statistic=-6.744489216483486, pvalue=3.0991945762476625e-11)
# Ttest_indResult(statistic=-6.8613727984006916, pvalue=1.4440070636590326e-11)
# Ttest_indResult(statistic=-7.1459084628780074, pvalue=2.1483535078217276e-12)
# Ttest_indResult(statistic=-6.1383454252567153, pvalue=1.3602234620687576e-09)
# Ttest_indResult(statistic=-4.0831888145632194, pvalue=4.9301164640547053e-05)
# Ttest_indResult(statistic=-11.471673605264808, pvalue=3.9635957706883941e-28)
# Ttest_indResult(statistic=-10.525160064262499, pvalue=3.1588247717947575e-24)
# ...

# %%
mon = purrcilla[purrcilla.DayOfWeek == 0]
fri = purrcilla[purrcilla.DayOfWeek == 4]

print(np.mean(fri['HRSeg1']), np.mean(mon['HRSeg1']))
print(np.mean(fri['HRSeg2A']), np.mean(mon['HRSeg2A']))
print(np.mean(fri['HRSeg2']), np.mean(mon['HRSeg2']))
print(np.mean(fri['HRSeg3']), np.mean(mon['HRSeg3']))
print(np.mean(fri['HRSeg4']), np.mean(mon['HRSeg4']))
print(np.mean(fri['FlowSeg1']), np.mean(mon['FlowSeg1']))
print(np.mean(fri['FlowSeg2A']), np.mean(mon['FlowSeg2A']))
print(np.mean(fri['FlowSeg2']), np.mean(mon['FlowSeg2']))
print(np.mean(fri['FlowSeg3']), np.mean(mon['FlowSeg3']))
print(np.mean(fri['FlowSeg4']), np.mean(mon['FlowSeg4']))

print(sp.stats.ttest_ind(fri['HRSeg1'], mon['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2A'], mon['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2'], mon['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg3'], mon['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg4'], mon['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg1'], mon['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2A'], mon['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2'], mon['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg3'], mon['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg4'], mon['FlowSeg4'], equal_var=False))
# Out:
# 160.3310344827586 166.86092715231788
# 160.35862068965517 167.94701986754967
# 161.93103448275863 169.27152317880794
# 172.1103448275862 177.08609271523179
# 174.31724137931033 178.56953642384107
# 25.57479108774713 26.320372550993394
# 25.24541884464366 26.01778010821194
# 25.21273262836782 25.971997790242835
# 23.22270387652875 24.779081035673304
# 22.382679312526417 23.873444267704187
# Ttest_indResult(statistic=-6.4002751919481931, pvalue=2.5485461928233206e-10)
# Ttest_indResult(statistic=-7.2902728964513779, pvalue=6.8913182680054213e-13)
# Ttest_indResult(statistic=-7.1644965842149633, pvalue=1.6550891329727412e-12)
# Ttest_indResult(statistic=-4.553024437362196, pvalue=6.0526564685435958e-06)
# Ttest_indResult(statistic=-3.0439113799059805, pvalue=0.0024079253676639401)
# Ttest_indResult(statistic=-1.7658820959635513, pvalue=0.077770051726545816)
# Ttest_indResult(statistic=-1.8129362245307081, pvalue=0.070184583916587773)
# ...

# %%
trial6 = nitro[nitro.RunID >= 6]
trial1 = nitro[nitro.RunID < 2]
print(np.mean(trial6['HRSeg1']), np.mean(trial1['HRSeg1']))
print(np.mean(trial6['HRSeg2A']), np.mean(trial1['HRSeg2A']))
print(np.mean(trial6['HRSeg2']), np.mean(trial1['HRSeg2']))
print(np.mean(trial6['HRSeg3']), np.mean(trial1['HRSeg3']))
print(np.mean(trial6['HRSeg4']), np.mean(trial1['HRSeg4']))
print(np.mean(trial6['FlowSeg1']), np.mean(trial1['FlowSeg1']))
print(np.mean(trial6['FlowSeg2A']), np.mean(trial1['FlowSeg2A']))
print(np.mean(trial6['FlowSeg2']), np.mean(trial1['FlowSeg2']))
print(np.mean(trial6['FlowSeg3']), np.mean(trial1['FlowSeg3']))
print(np.mean(trial6['FlowSeg4']), np.mean(trial1['FlowSeg4']))

print(sp.stats.ttest_ind(trial6['HRSeg1'], trial1['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2A'], trial1['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg2'], trial1['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg3'], trial1['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['HRSeg4'], trial1['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg1'], trial1['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2A'], trial1['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg2'], trial1['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg3'], trial1['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(trial6['FlowSeg4'], trial1['FlowSeg4'], equal_var=False))
# Out:
# 136.10526315789474 140.53333333333333
# 138.31578947368422 140.0
# 140.52631578947367 141.6
# 156.94736842105263 158.66666666666666
# 145.26315789473685 142.4
# 19.792229175789483 21.257778891333334
# 20.00969480210527 21.235127807777772
# 19.969744029210524 20.922593645777777
# 20.670790718684206 20.415890086888886
# 21.057367240526315 21.132598291333338
# Ttest_indResult(statistic=-1.6114761219324332, pvalue=0.11120573262381644)
# Ttest_indResult(statistic=-0.77477723765062889, pvalue=0.44097325966901835)
# Ttest_indResult(statistic=-0.42839307781322689, pvalue=0.6695020431958989)
# Ttest_indResult(statistic=-0.37104260113723825, pvalue=0.71157457449676653)
# Ttest_indResult(statistic=0.56045069403364489, pvalue=0.5774404893217151)
# Ttest_indResult(statistic=-1.514480396208582, pvalue=0.13400702210322477)
# Ttest_indResult(statistic=-1.2577865512224309, pvalue=0.21218904869906835)
# Ttest_indResult(statistic=-0.89970846822137396, pvalue=0.37094468265637692)
# ...

# %%
mon = nitro[nitro.DayOfWeek == 0]
fri = nitro[nitro.DayOfWeek == 4]

print(np.mean(fri['HRSeg1']), np.mean(mon['HRSeg1']))
print(np.mean(fri['HRSeg2A']), np.mean(mon['HRSeg2A']))
print(np.mean(fri['HRSeg2']), np.mean(mon['HRSeg2']))
print(np.mean(fri['HRSeg3']), np.mean(mon['HRSeg3']))
print(np.mean(fri['HRSeg4']), np.mean(mon['HRSeg4']))
print(np.mean(fri['FlowSeg1']), np.mean(mon['FlowSeg1']))
print(np.mean(fri['FlowSeg2A']), np.mean(mon['FlowSeg2A']))
print(np.mean(fri['FlowSeg2']), np.mean(mon['FlowSeg2']))
print(np.mean(fri['FlowSeg3']), np.mean(mon['FlowSeg3']))
print(np.mean(fri['FlowSeg4']), np.mean(mon['FlowSeg4']))

print(sp.stats.ttest_ind(fri['HRSeg1'], mon['HRSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2A'], mon['HRSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg2'], mon['HRSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg3'], mon['HRSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['HRSeg4'], mon['HRSeg4'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg1'], mon['FlowSeg1'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2A'], mon['FlowSeg2A'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg2'], mon['FlowSeg2'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg3'], mon['FlowSeg3'], equal_var=False))
print(sp.stats.ttest_ind(fri['FlowSeg4'], mon['FlowSeg4'], equal_var=False))
# Out:
# 133.2 133.15068493150685
# 135.0 135.12328767123287
# 137.6 134.46575342465752
# 158.2 154.02739726027397
# 137.8 135.6164383561644
# 24.537139541000005 18.325091473287664
# 24.167412306999996 18.35773423520548
# 23.971063839333333 18.041909263561635
# 23.6066355045 19.93228199890411
# 23.55129812266666 21.061249441643845
# Ttest_indResult(statistic=0.028704183407086737, pvalue=0.97714961938408962)
# Ttest_indResult(statistic=-0.076689995288565349, pvalue=0.93900039814183378)
# Ttest_indResult(statistic=1.6460948910822626, pvalue=0.10288999027246673)
# Ttest_indResult(statistic=1.0529732901598183, pvalue=0.29493873792292769)
# Ttest_indResult(statistic=1.1983397256323864, pvalue=0.23299892108919951)
# Ttest_indResult(statistic=11.101460208659203, pvalue=5.9258712656890414e-20)
# Ttest_indResult(statistic=10.375189097827112, pvalue=2.2315208059827863e-18)
# Ttest_indResult(statistic=9.9721148915218958, pvalue=4.3599304358594434e-17)
# ...

# %%
#HR Over Day
plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='RunID',y='HRSeg1', data = df, hue='CatName')
plt.title("HR Segment 1 - Over Day")
plt.xlabel('Run ID')
plt.ylabel("HR Seg1")
plt.ylim(0,350)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverDay_HRSeg1.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='RunID',y='HRSeg2A', data = df, hue='CatName')
plt.title("HR Segment 2A - Over Day")
plt.xlabel('Run ID')
plt.ylabel("HR Seg2A")
plt.ylim(0,350)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverDay_HRSeg2A.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='RunID',y='HRSeg2', data = df, hue='CatName')
plt.title("HR Segment 2 - Over Day")
plt.xlabel('Run ID')
plt.ylabel("HR Seg2")
plt.ylim(0,350)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverDay_HRSeg2.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='RunID',y='HRSeg3', data = df, hue='CatName')
plt.title("HR Segment 3 - Over Day")
plt.xlabel('Run ID')
plt.ylabel("HR Seg3")
plt.ylim(0,350)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverDay_HRSeg3.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='RunID',y='HRSeg4', data = df, hue='CatName')
plt.title("HR Segment 4  - Over Day")
plt.xlabel('Run ID')
plt.ylabel("HR Seg4")
plt.ylim(0,350)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverDay_HRSeg4.png', dpi=500)
plt.close()

#Flow Over Day
plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='RunID',y='FlowSeg1', data = df, hue='CatName')
plt.title("Flow Segment 1 - Over Day")
plt.xlabel('Run ID')
plt.ylabel("Flow Seg1")
plt.ylim(0,100)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverDay_FlowSeg1.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='RunID',y='FlowSeg2A', data = df, hue='CatName')
plt.title("Flow Segment 2A - Over Day")
plt.xlabel('Run ID')
plt.ylabel("Flow Seg2A")
plt.ylim(0,100)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverDay_FlowSeg2A.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='RunID',y='FlowSeg2', data = df, hue='CatName')
plt.title("Flow Segment 2 - Over Day")
plt.xlabel('Run ID')
plt.ylabel("Flow Seg2")
plt.ylim(0,100)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverDay_FlowSeg2.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='RunID',y='FlowSeg3', data = df, hue='CatName')
plt.title("Flow Segment 3 - Over Day")
plt.xlabel('Run ID')
plt.ylabel("Flow Seg3")
plt.ylim(0,100)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverDay_FlowSeg3.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='RunID',y='FlowSeg4', data = df, hue='CatName')
plt.title("Flow Segment 4  - Over Day")
plt.xlabel('Run ID')
plt.ylabel("Flow Seg4")
plt.ylim(0,100)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverDay_FlowSeg4.png', dpi=500)
plt.close()

# %%
#HR Over Week
plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='DayOfWeek',y='HRSeg1', data = df, hue='CatName')
plt.title("HR Segment 1 - Over Week")
plt.xlabel('Day of Week')
plt.ylabel("HR Seg1")
plt.ylim(0,350)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverWeek_HRSeg1.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='DayOfWeek',y='HRSeg2A', data = df, hue='CatName')
plt.title("HR Segment 2A - Over Week")
plt.xlabel('Day of Week')
plt.ylabel("HR Seg2A")
plt.ylim(0,350)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverWeek_HRSeg2A.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='DayOfWeek',y='HRSeg2', data = df, hue='CatName')
plt.title("HR Segment 2 - Over Week")
plt.xlabel('Day of Week')
plt.ylabel("HR Seg2")
plt.ylim(0,350)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverWeek_HRSeg2.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='DayOfWeek',y='HRSeg3', data = df, hue='CatName')
plt.title("HR Segment 3 - Over Week")
plt.xlabel('Day of Week')
plt.ylabel("HR Seg3")
plt.ylim(0,350)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverWeek_HRSeg3.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='DayOfWeek',y='HRSeg4', data = df, hue='CatName')
plt.title("HR Segment 4  - Over Week")
plt.xlabel('Day of Week')
plt.ylabel("HR Seg4")
plt.ylim(0,350)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverWeek_HRSeg4.png', dpi=500)
plt.close()

#Flow Over Week
plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='DayOfWeek',y='FlowSeg1', data = df, hue='CatName')
plt.title("Flow Segment 1 - Over Week")
plt.xlabel('Day of Week')
plt.ylabel("Flow Seg1")
plt.ylim(0,100)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverWeek_FlowSeg1.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='DayOfWeek',y='FlowSeg2A', data = df, hue='CatName')
plt.title("Flow Segment 2A - Over Week")
plt.xlabel('Day of Week')
plt.ylabel("Flow Seg2A")
plt.ylim(0,100)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverWeek_FlowSeg2A.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='DayOfWeek',y='FlowSeg2', data = df, hue='CatName')
plt.title("Flow Segment 2 - Over Week")
plt.xlabel('Day of Week')
plt.ylabel("Flow Seg2")
plt.ylim(0,100)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverWeek_FlowSeg2.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='DayOfWeek',y='FlowSeg3', data = df, hue='CatName')
plt.title("Flow Segment 3 - Over Week")
plt.xlabel('Day of Week')
plt.ylabel("Flow Seg3")
plt.ylim(0,100)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverWeek_FlowSeg3.png', dpi=500)
plt.close()

plt.clf()
sns.set(style='whitegrid',context='paper')
sns.lmplot(x='DayOfWeek',y='FlowSeg4', data = df, hue='CatName')
plt.title("Flow Segment 4  - Over Week")
plt.xlabel('Day of Week')
plt.ylabel("Flow Seg4")
plt.ylim(0,100)
#plt.figure(figsize=(8,10))
plt.savefig('../../results/fig/OverWeek_FlowSeg4.png', dpi=500)
plt.close()

# %% [markdown]
# # First Week v. Last Week
#
# ## First Week:

# %%
firstWeekData = pd.read_csv("../../data/proc/allcats_cleaned_firstWeek.txt", sep= '\t')
lastWeekData = pd.read_csv("../../data/proc/allcats_cleaned_lastWeek.txt", sep = '\t')

firstWeekData.head()
# Out:
#       Date  RunID  TiltAmp    TiltVel  TiltToLightTime  HRSeg1   FlowSeg1  \
# 0  4/14/14    1.2       60  33.822527         10.60736     192  15.846680
# 1  4/14/14    1.3       60  38.685711         10.18904     168  16.591424
# 2  4/14/14    1.4       60  38.426960         10.08944     204  18.848599
# 3  4/14/14    1.5       60  41.588288         10.52768     180  19.250943
# 4  4/14/14    2.1       60  42.361841         10.05956     168  18.906974
#
#    HRSeg2A  FlowSeg2A  HRSeg2   ...     FlowSeg3  HRSeg4   FlowSeg4  Comments  \
# 0      168  18.619668     168   ...    17.088212     192  18.424471       NaN
# 1      192  18.583448     192   ...    17.185249     180  18.166914       NaN
# 2      180  18.384433     180   ...    17.166065     192  17.904955       NaN
# 3      192  17.675648     192   ...    18.290926     216  17.723181       NaN
# 4      216  19.913778     192   ...    17.002022     192  19.741140       NaN
#
# ...

# %%
#Overall:

firstWeek_HR1 = firstWeekData["HRSeg1"]
firstWeek_HR2A = firstWeekData["HRSeg2A"]
firstWeek_HR2 = firstWeekData["HRSeg2"]
firstWeek_HR3 = firstWeekData["HRSeg3"]
firstWeek_HR4 = firstWeekData["HRSeg4"]

#Flow segments:
firstWeek_BF1 = firstWeekData["FlowSeg1"]
firstWeek_BF2A = firstWeekData["FlowSeg2"]
firstWeek_BF2 = firstWeekData["FlowSeg2A"]
firstWeek_BF3 = firstWeekData["FlowSeg3"]
firstWeek_BF4 = firstWeekData["FlowSeg4"]

#Overall:

lastWeek_HR1 = lastWeekData["HRSeg1"]
lastWeek_HR2A = lastWeekData["HRSeg2A"]
lastWeek_HR2 = lastWeekData["HRSeg2"]
lastWeek_HR3 = lastWeekData["HRSeg3"]
lastWeek_HR4 = lastWeekData["HRSeg4"]

#Flow segments:
lastWeek_BF1 = lastWeekData["FlowSeg1"]
lastWeek_BF2A = lastWeekData["FlowSeg2"]
lastWeek_BF2 = lastWeekData["FlowSeg2A"]
lastWeek_BF3 = lastWeekData["FlowSeg3"]
lastWeek_BF4 = lastWeekData["FlowSeg4"]

#segmentList = [firstWeek_HR1, firstWeek_HR2A, firstWeek_HR2, firstWeek_HR3, firstWeek_HR4, firstWeek_BF1, firstWeek_BF2A, firstWeek_BF2, firstWeek_BF3, firstWeek_BF4]

print(sp.stats.ttest_ind(firstWeek_HR1.dropna(), lastWeek_HR1.dropna(), equal_var=False))
print(sp.stats.ttest_ind(firstWeek_HR2A.dropna(), lastWeek_HR2A.dropna(), equal_var=False))
print(sp.stats.ttest_ind(firstWeek_HR2.dropna(), lastWeek_HR2.dropna(), equal_var=False))
print(sp.stats.ttest_ind(firstWeek_HR3.dropna(), lastWeek_HR3.dropna(), equal_var=False))
print(sp.stats.ttest_ind(firstWeek_HR4.dropna(), lastWeek_HR4.dropna(), equal_var=False))

print(sp.stats.ttest_ind(firstWeek_BF1.dropna(), lastWeek_BF1.dropna(), equal_var=False))
print(sp.stats.ttest_ind(firstWeek_BF2A.dropna(), lastWeek_BF2A.dropna(), equal_var=False))
print(sp.stats.ttest_ind(firstWeek_BF2.dropna(), lastWeek_BF2.dropna(), equal_var=False))
print(sp.stats.ttest_ind(firstWeek_BF3.dropna(), lastWeek_BF3.dropna(), equal_var=False))
print(sp.stats.ttest_ind(firstWeek_BF4.dropna(), lastWeek_BF4.dropna(), equal_var=False))
# Out:
# Ttest_indResult(statistic=-1.6097313282100452, pvalue=0.10768280728129359)
# Ttest_indResult(statistic=-2.7668331590425259, pvalue=0.0057357941035487995)
# Ttest_indResult(statistic=-3.0545081022550895, pvalue=0.0022969136946837912)
# Ttest_indResult(statistic=-4.4404010651601462, pvalue=9.6965356934747408e-06)
# Ttest_indResult(statistic=-6.2717844576480033, pvalue=4.755828109695833e-10)
# Ttest_indResult(statistic=5.6829056467295347, pvalue=1.6397611732522911e-08)
# Ttest_indResult(statistic=6.2196502603306945, pvalue=6.7196058846877471e-10)
# Ttest_indResult(statistic=6.0863443294020332, pvalue=1.5240508306630108e-09)
# Ttest_indResult(statistic=5.5252791584392051, pvalue=3.9383671436400845e-08)
# Ttest_indResult(statistic=5.5458497758185699, pvalue=3.5061278073549209e-08)

# %%
maverick_firstWeek = firstWeekData[firstWeekData.CatName == 'Maverick']
maverick_lastWeek = lastWeekData[lastWeekData.CatName == 'Maverick']
boo_firstWeek = firstWeekData[firstWeekData.CatName == 'Boo']
boo_lastWeek = lastWeekData[lastWeekData.CatName == 'Boo']
nitro_firstWeek = firstWeekData[firstWeekData.CatName == 'Nitro']
nitro_lastWeek = lastWeekData[lastWeekData.CatName == 'Nitro']
shakespurr_firstWeek = firstWeekData[firstWeekData.CatName == 'Shakespurr']
shakespurr_lastWeek = lastWeekData[lastWeekData.CatName == 'Shakespurr']
purrcilla_firstWeek = firstWeekData[firstWeekData.CatName == 'Purrcilla']
purrcilla_lastWeek = lastWeekData[lastWeekData.CatName == 'Purrcilla']
clifford_firstWeek = firstWeekData[firstWeekData.CatName == 'Clifford']
clifford_lastWeek = lastWeekData[lastWeekData.CatName == 'Clifford']

# %% [markdown]
# ### Stats - Maverick

# %%
print(sp.stats.ttest_ind(maverick_firstWeek['HRSeg1'].dropna(), maverick_lastWeek['HRSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(maverick_firstWeek['HRSeg2A'].dropna(), maverick_lastWeek['HRSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(maverick_firstWeek['HRSeg2'].dropna(), maverick_lastWeek['HRSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(maverick_firstWeek['HRSeg3'].dropna(), maverick_lastWeek['HRSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(maverick_firstWeek['HRSeg4'].dropna(), maverick_lastWeek['HRSeg4'].dropna(), equal_var=False))
print(np.mean(maverick_firstWeek['HRSeg1'].dropna()), np.mean(maverick_lastWeek['HRSeg1'].dropna()))
print(np.mean(maverick_firstWeek['HRSeg2A'].dropna()), np.mean(maverick_lastWeek['HRSeg2A'].dropna()))
print(np.mean(maverick_firstWeek['HRSeg2'].dropna()), np.mean(maverick_lastWeek['HRSeg2'].dropna()))
print(np.mean(maverick_firstWeek['HRSeg3'].dropna()), np.mean(maverick_lastWeek['HRSeg3'].dropna()))
print(np.mean(maverick_firstWeek['HRSeg4'].dropna()), np.mean(maverick_lastWeek['HRSeg4'].dropna()))
# Out:
# Ttest_indResult(statistic=2.1555277640854205, pvalue=0.03243615862574465)
# Ttest_indResult(statistic=2.1080857444587129, pvalue=0.036423455641869371)
# Ttest_indResult(statistic=2.3881919973340771, pvalue=0.018066417724106599)
# Ttest_indResult(statistic=3.6141775587971963, pvalue=0.00041664745988359266)
# Ttest_indResult(statistic=3.826892638209813, pvalue=0.00017856484801648086)
# 141.84172661870502 136.36363636363637
# 141.58273381294964 136.25454545454545
# 141.75539568345323 135.4909090909091
# 154.27338129496403 142.8
# 147.28057553956833 137.8909090909091

# %%
print(sp.stats.ttest_ind(maverick_firstWeek['FlowSeg1'].dropna(), maverick_lastWeek['FlowSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(maverick_firstWeek['FlowSeg2A'].dropna(), maverick_lastWeek['FlowSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(maverick_firstWeek['FlowSeg2'].dropna(), maverick_lastWeek['FlowSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(maverick_firstWeek['FlowSeg3'].dropna(), maverick_lastWeek['FlowSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(maverick_firstWeek['FlowSeg4'].dropna(), maverick_lastWeek['FlowSeg4'].dropna(), equal_var=False))

print(np.mean(maverick_firstWeek['FlowSeg1'].dropna()), np.mean(maverick_lastWeek['FlowSeg1'].dropna()))
print(np.mean(maverick_firstWeek['FlowSeg2A'].dropna()), np.mean(maverick_lastWeek['FlowSeg2A'].dropna()))
print(np.mean(maverick_firstWeek['FlowSeg2'].dropna()), np.mean(maverick_lastWeek['FlowSeg2'].dropna()))
print(np.mean(maverick_firstWeek['FlowSeg3'].dropna()), np.mean(maverick_lastWeek['FlowSeg3'].dropna()))
print(np.mean(maverick_firstWeek['FlowSeg4'].dropna()), np.mean(maverick_lastWeek['FlowSeg4'].dropna()))
# Out:
# Ttest_indResult(statistic=21.193712195840664, pvalue=2.6285109990519942e-46)
# Ttest_indResult(statistic=20.209599530005118, pvalue=2.6050751200566304e-44)
# Ttest_indResult(statistic=19.855177495986766, pvalue=3.4458595399328493e-43)
# Ttest_indResult(statistic=17.273518850319611, pvalue=5.718595035181158e-36)
# Ttest_indResult(statistic=15.755275127608309, pvalue=8.4879104531794963e-32)
# 25.498292935251797 9.562424106281819
# 24.65394944604316 9.586171626836363
# 24.384106870503597 9.486988879509088
# 22.935182538129478 8.806786617609092
# 23.577088413669077 9.753654008254548

# %% [markdown]
# Maverick - all segments significant first to last week
#
# ### Boo
# All segments significant first week to last week.

# %%
boo_firstWeek['Date']
# Out:
# 0     4/14/14
# 1     4/14/14
# 2     4/14/14
# 3     4/14/14
# 4     4/14/14
# 5     4/14/14
# 6     4/14/14
# 7     4/14/14
# 8     4/14/14
# 9     4/14/14
# 10    4/14/14
# 11    4/14/14
# 12    4/14/14
# 13    4/14/14
# 14    4/14/14
# 15    4/14/14
# 16    4/14/14
# 17    4/14/14
# 18    4/14/14
# 19    4/14/14
# 20    4/14/14
# 21    4/14/14
# 22    4/14/14
# 23    4/14/14
# 24    4/17/14
# 25    4/17/14
# 26    4/17/14
# 27    4/17/14
# 28    4/17/14
# 29    4/17/14
# 30    4/17/14
# 31    4/17/14
# 32    4/17/14
# 33    4/17/14
# 34    4/17/14
# 35    4/17/14
# 36    4/17/14
# 37    4/17/14
# 38    4/17/14
# 39    4/18/14
# 40    4/18/14
# 41    4/18/14
# 42    4/18/14
# 43    4/18/14
# 44    4/18/14
# 45    4/18/14
# 46    4/18/14
# 47    4/18/14
# 48    4/18/14
# 49    4/18/14
# 50    4/18/14
# 51    4/18/14
# 52    4/18/14
# 53    4/18/14
# 54    4/18/14
# Name: Date, dtype: object

# %%
print(sp.stats.ttest_ind(boo_firstWeek['HRSeg1'].dropna(), boo_lastWeek['HRSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(boo_firstWeek['HRSeg2A'].dropna(), boo_lastWeek['HRSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(boo_firstWeek['HRSeg2'].dropna(), boo_lastWeek['HRSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(boo_firstWeek['HRSeg3'].dropna(), boo_lastWeek['HRSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(boo_firstWeek['HRSeg4'].dropna(), boo_lastWeek['HRSeg4'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(boo_firstWeek['FlowSeg1'].dropna(), boo_lastWeek['FlowSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(boo_firstWeek['FlowSeg2A'].dropna(), boo_lastWeek['FlowSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(boo_firstWeek['FlowSeg2'].dropna(), boo_lastWeek['FlowSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(boo_firstWeek['FlowSeg3'].dropna(), boo_lastWeek['FlowSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(boo_firstWeek['FlowSeg4'].dropna(), boo_lastWeek['FlowSeg4'].dropna(), equal_var=False))

print(np.mean(boo_firstWeek['HRSeg1'].dropna()), np.mean(boo_lastWeek['HRSeg1'].dropna()))
print(np.mean(boo_firstWeek['HRSeg2A'].dropna()), np.mean(boo_lastWeek['HRSeg2A'].dropna()))
print(np.mean(boo_firstWeek['HRSeg2'].dropna()), np.mean(boo_lastWeek['HRSeg2'].dropna()))
print(np.mean(boo_firstWeek['HRSeg3'].dropna()), np.mean(boo_lastWeek['HRSeg3'].dropna()))
print(np.mean(boo_firstWeek['HRSeg4'].dropna()), np.mean(boo_lastWeek['HRSeg4'].dropna()))
print(np.mean(boo_firstWeek['FlowSeg1'].dropna()), np.mean(boo_lastWeek['FlowSeg1'].dropna()))
print(np.mean(boo_firstWeek['FlowSeg2A'].dropna()), np.mean(boo_lastWeek['FlowSeg2A'].dropna()))
print(np.mean(boo_firstWeek['FlowSeg2'].dropna()), np.mean(boo_lastWeek['FlowSeg2'].dropna()))
print(np.mean(boo_firstWeek['FlowSeg3'].dropna()), np.mean(boo_lastWeek['FlowSeg3'].dropna()))
print(np.mean(boo_firstWeek['FlowSeg4'].dropna()), np.mean(boo_lastWeek['FlowSeg4'].dropna()))
# Out:
# Ttest_indResult(statistic=8.8047999332368576, pvalue=6.1419319001011984e-14)
# Ttest_indResult(statistic=7.6063251714664686, pvalue=4.0466280254153274e-11)
# Ttest_indResult(statistic=7.9289273002881364, pvalue=8.5368938352536693e-12)
# Ttest_indResult(statistic=8.6165375322161637, pvalue=5.7795912047001302e-13)
# Ttest_indResult(statistic=4.8116519341701052, pvalue=3.4395663209310847e-06)
# Ttest_indResult(statistic=17.536018354691731, pvalue=4.4775708424475416e-41)
# Ttest_indResult(statistic=17.237636458718558, pvalue=4.581568551053977e-40)
# Ttest_indResult(statistic=18.149692613967243, pvalue=1.6212672472631096e-42)
# Ttest_indResult(statistic=16.576972223913049, pvalue=1.415266710195564e-38)
# Ttest_indResult(statistic=19.114166056101752, pvalue=8.1259583776342256e-46)
# 164.29090909090908 141.97058823529412
# 165.6 143.2058823529412
# 166.47272727272727 144.44117647058823
# 189.8181818181818 161.11764705882354
# 181.96363636363637 165.7941176470588
# ...

# %% [markdown]
# ### Nitro
# Only HR S3 and S4, BF 2, 2A are significant.

# %%
print(sp.stats.ttest_ind(nitro_firstWeek['HRSeg1'].dropna(), nitro_lastWeek['HRSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(nitro_firstWeek['HRSeg2A'].dropna(), nitro_lastWeek['HRSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(nitro_firstWeek['HRSeg2'].dropna(), nitro_lastWeek['HRSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(nitro_firstWeek['HRSeg3'].dropna(), nitro_lastWeek['HRSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(nitro_firstWeek['HRSeg4'].dropna(), nitro_lastWeek['HRSeg4'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(nitro_firstWeek['FlowSeg1'].dropna(), nitro_lastWeek['FlowSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(nitro_firstWeek['FlowSeg2A'].dropna(), nitro_lastWeek['FlowSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(nitro_firstWeek['FlowSeg2'].dropna(), nitro_lastWeek['FlowSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(nitro_firstWeek['FlowSeg3'].dropna(), nitro_lastWeek['FlowSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(nitro_firstWeek['FlowSeg4'].dropna(), nitro_lastWeek['FlowSeg4'].dropna(), equal_var=False))

print(np.mean(nitro_firstWeek['HRSeg1'].dropna()), np.mean(nitro_lastWeek['HRSeg1'].dropna()))
print(np.mean(nitro_firstWeek['HRSeg2A'].dropna()), np.mean(nitro_lastWeek['HRSeg2A'].dropna()))
print(np.mean(nitro_firstWeek['HRSeg2'].dropna()), np.mean(nitro_lastWeek['HRSeg2'].dropna()))
print(np.mean(nitro_firstWeek['HRSeg3'].dropna()), np.mean(nitro_lastWeek['HRSeg3'].dropna()))
print(np.mean(nitro_firstWeek['HRSeg4'].dropna()), np.mean(nitro_lastWeek['HRSeg4'].dropna()))
print(np.mean(nitro_firstWeek['FlowSeg1'].dropna()), np.mean(nitro_lastWeek['FlowSeg1'].dropna()))
print(np.mean(nitro_firstWeek['FlowSeg2A'].dropna()), np.mean(nitro_lastWeek['FlowSeg2A'].dropna()))
print(np.mean(nitro_firstWeek['FlowSeg2'].dropna()), np.mean(nitro_lastWeek['FlowSeg2'].dropna()))
print(np.mean(nitro_firstWeek['FlowSeg3'].dropna()), np.mean(nitro_lastWeek['FlowSeg3'].dropna()))
print(np.mean(nitro_firstWeek['FlowSeg4'].dropna()), np.mean(nitro_lastWeek['FlowSeg4'].dropna()))
# Out:
# Ttest_indResult(statistic=-0.15168190240822663, pvalue=0.87958118464007318)
# Ttest_indResult(statistic=-0.7987616065803288, pvalue=0.42524566761124161)
# Ttest_indResult(statistic=-1.3489454576284885, pvalue=0.17867302754720438)
# Ttest_indResult(statistic=-3.392770405157143, pvalue=0.00081342479830744184)
# Ttest_indResult(statistic=-3.6784979165549094, pvalue=0.00033366557141632959)
# Ttest_indResult(statistic=1.9349728176460448, pvalue=0.054239733979175926)
# Ttest_indResult(statistic=2.4949939775646675, pvalue=0.013312628266192525)
# Ttest_indResult(statistic=2.8181505711926964, pvalue=0.0052698420843056261)
# Ttest_indResult(statistic=1.1102670601097477, pvalue=0.26819953011379444)
# Ttest_indResult(statistic=-0.015622409915401208, pvalue=0.98755031049764375)
# 136.8 137.0420168067227
# 137.84347826086957 138.85714285714286
# 138.7826086956522 140.9747899159664
# 152.45217391304348 160.8403361344538
# 141.28695652173914 154.28571428571428
# 21.14525189330435 20.04128788882352
# ...

# %% [markdown]
# ### Purrcilla
# All HR segments signficant.
# Only BF S3 significant.

# %%
print(sp.stats.ttest_ind(purrcilla_firstWeek['HRSeg1'].dropna(), purrcilla_lastWeek['HRSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(purrcilla_firstWeek['HRSeg2A'].dropna(), purrcilla_lastWeek['HRSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(purrcilla_firstWeek['HRSeg2'].dropna(), purrcilla_lastWeek['HRSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(purrcilla_firstWeek['HRSeg3'].dropna(), purrcilla_lastWeek['HRSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(purrcilla_firstWeek['HRSeg4'].dropna(), purrcilla_lastWeek['HRSeg4'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(purrcilla_firstWeek['FlowSeg1'].dropna(), purrcilla_lastWeek['FlowSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(purrcilla_firstWeek['FlowSeg2A'].dropna(), purrcilla_lastWeek['FlowSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(purrcilla_firstWeek['FlowSeg2'].dropna(), purrcilla_lastWeek['FlowSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(purrcilla_firstWeek['FlowSeg3'].dropna(), purrcilla_lastWeek['FlowSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(purrcilla_firstWeek['FlowSeg4'].dropna(), purrcilla_lastWeek['FlowSeg4'].dropna(), equal_var=False))

print(np.mean(purrcilla_firstWeek['HRSeg1'].dropna()), np.mean(purrcilla_lastWeek['HRSeg1'].dropna()))
print(np.mean(purrcilla_firstWeek['HRSeg2A'].dropna()), np.mean(purrcilla_lastWeek['HRSeg2A'].dropna()))
print(np.mean(purrcilla_firstWeek['HRSeg2'].dropna()), np.mean(purrcilla_lastWeek['HRSeg2'].dropna()))
print(np.mean(purrcilla_firstWeek['HRSeg3'].dropna()), np.mean(purrcilla_lastWeek['HRSeg3'].dropna()))
print(np.mean(purrcilla_firstWeek['HRSeg4'].dropna()), np.mean(purrcilla_lastWeek['HRSeg4'].dropna()))
print(np.mean(purrcilla_firstWeek['FlowSeg1'].dropna()), np.mean(purrcilla_lastWeek['FlowSeg1'].dropna()))
print(np.mean(purrcilla_firstWeek['FlowSeg2A'].dropna()), np.mean(purrcilla_lastWeek['FlowSeg2A'].dropna()))
print(np.mean(purrcilla_firstWeek['FlowSeg2'].dropna()), np.mean(purrcilla_lastWeek['FlowSeg2'].dropna()))
print(np.mean(purrcilla_firstWeek['FlowSeg3'].dropna()), np.mean(purrcilla_lastWeek['FlowSeg3'].dropna()))
print(np.mean(purrcilla_firstWeek['FlowSeg4'].dropna()), np.mean(purrcilla_lastWeek['FlowSeg4'].dropna()))
# Out:
# Ttest_indResult(statistic=-9.8406465865566606, pvalue=1.4048221090004495e-19)
# Ttest_indResult(statistic=-12.16285922172041, pvalue=3.8309217756517788e-27)
# Ttest_indResult(statistic=-12.595193926919364, pvalue=1.2875487267568197e-28)
# Ttest_indResult(statistic=-14.150246168641502, pvalue=5.7648585913667122e-34)
# Ttest_indResult(statistic=-13.578869599554675, pvalue=5.4595476720557765e-32)
# Ttest_indResult(statistic=-0.42558114467854441, pvalue=0.67079236167354994)
# Ttest_indResult(statistic=0.379077610850104, pvalue=0.70496713009554735)
# Ttest_indResult(statistic=0.041869438180682693, pvalue=0.96663644634453805)
# Ttest_indResult(statistic=2.5751243338866687, pvalue=0.010605594137245093)
# Ttest_indResult(statistic=-1.1456974366541028, pvalue=0.25310501529894025)
# 152.45901639344262 168.26470588235293
# 149.21311475409837 168.0
# 150.0 168.44117647058823
# 156.78688524590163 178.41176470588235
# 158.36065573770492 181.14705882352942
# 22.661987817622958 22.876613573308813
# ...

# %% [markdown]
# ### Shakespurr
# Only HR S3 sig
# All BF significant

# %%
print(sp.stats.ttest_ind(shakespurr_firstWeek['HRSeg1'].dropna(), shakespurr_lastWeek['HRSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(shakespurr_firstWeek['HRSeg2A'].dropna(), shakespurr_lastWeek['HRSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(shakespurr_firstWeek['HRSeg2'].dropna(), shakespurr_lastWeek['HRSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(shakespurr_firstWeek['HRSeg3'].dropna(), shakespurr_lastWeek['HRSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(shakespurr_firstWeek['HRSeg4'].dropna(), shakespurr_lastWeek['HRSeg4'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(shakespurr_firstWeek['FlowSeg1'].dropna(), shakespurr_lastWeek['FlowSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(shakespurr_firstWeek['FlowSeg2A'].dropna(), shakespurr_lastWeek['FlowSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(shakespurr_firstWeek['FlowSeg2'].dropna(), shakespurr_lastWeek['FlowSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(shakespurr_firstWeek['FlowSeg3'].dropna(), shakespurr_lastWeek['FlowSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(shakespurr_firstWeek['FlowSeg4'].dropna(), shakespurr_lastWeek['FlowSeg4'].dropna(), equal_var=False))

print(np.mean(shakespurr_firstWeek['HRSeg1'].dropna()), np.mean(shakespurr_lastWeek['HRSeg1'].dropna()))
print(np.mean(shakespurr_firstWeek['HRSeg2A'].dropna()), np.mean(shakespurr_lastWeek['HRSeg2A'].dropna()))
print(np.mean(shakespurr_firstWeek['HRSeg2'].dropna()), np.mean(shakespurr_lastWeek['HRSeg2'].dropna()))
print(np.mean(shakespurr_firstWeek['HRSeg3'].dropna()), np.mean(shakespurr_lastWeek['HRSeg3'].dropna()))
print(np.mean(shakespurr_firstWeek['HRSeg4'].dropna()), np.mean(shakespurr_lastWeek['HRSeg4'].dropna()))
print(np.mean(shakespurr_firstWeek['FlowSeg1'].dropna()), np.mean(shakespurr_lastWeek['FlowSeg1'].dropna()))
print(np.mean(shakespurr_firstWeek['FlowSeg2A'].dropna()), np.mean(shakespurr_lastWeek['FlowSeg2A'].dropna()))
print(np.mean(shakespurr_firstWeek['FlowSeg2'].dropna()), np.mean(shakespurr_lastWeek['FlowSeg2'].dropna()))
print(np.mean(shakespurr_firstWeek['FlowSeg3'].dropna()), np.mean(shakespurr_lastWeek['FlowSeg3'].dropna()))
print(np.mean(shakespurr_firstWeek['FlowSeg4'].dropna()), np.mean(shakespurr_lastWeek['FlowSeg4'].dropna()))
# Out:
# Ttest_indResult(statistic=0.23961579760766885, pvalue=0.81083129798700493)
# Ttest_indResult(statistic=-0.87462239835076994, pvalue=0.38267441363390498)
# Ttest_indResult(statistic=-2.8484330206022381, pvalue=0.0047870263383990638)
# Ttest_indResult(statistic=1.4473043656330209, pvalue=0.14909186072945066)
# Ttest_indResult(statistic=1.4218968874497853, pvalue=0.15649421988261575)
# Ttest_indResult(statistic=14.469994466771787, pvalue=1.1574869850191576e-34)
# Ttest_indResult(statistic=17.148972616179762, pvalue=1.1651688762786151e-43)
# Ttest_indResult(statistic=16.180027799721135, pvalue=1.9792671492880011e-40)
# Ttest_indResult(statistic=16.591746331436177, pvalue=6.951761971772141e-42)
# Ttest_indResult(statistic=17.474257006988349, pvalue=1.3714226843668965e-44)
# 163.06542056074767 162.68571428571428
# 161.49532710280374 162.85714285714286
# 160.5981308411215 164.82857142857142
# 171.70093457943926 169.62857142857143
# 174.16822429906543 171.85714285714286
# ...

# %% [markdown]
# ### Clifford
#
# All segments significant.

# %%
print(sp.stats.ttest_ind(clifford_firstWeek['HRSeg1'].dropna(), clifford_lastWeek['HRSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(clifford_firstWeek['HRSeg2A'].dropna(), clifford_lastWeek['HRSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(clifford_firstWeek['HRSeg2'].dropna(), clifford_lastWeek['HRSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(clifford_firstWeek['HRSeg3'].dropna(), clifford_lastWeek['HRSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(clifford_firstWeek['HRSeg4'].dropna(), clifford_lastWeek['HRSeg4'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(clifford_firstWeek['FlowSeg1'].dropna(), clifford_lastWeek['FlowSeg1'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(clifford_firstWeek['FlowSeg2A'].dropna(), clifford_lastWeek['FlowSeg2A'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(clifford_firstWeek['FlowSeg2'].dropna(), clifford_lastWeek['FlowSeg2'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(clifford_firstWeek['FlowSeg3'].dropna(), clifford_lastWeek['FlowSeg3'].dropna(), equal_var=False))
print(sp.stats.ttest_ind(clifford_firstWeek['FlowSeg4'].dropna(), clifford_lastWeek['FlowSeg4'].dropna(), equal_var=False))

print(np.mean(clifford_firstWeek['HRSeg1'].dropna()), np.mean(clifford_lastWeek['HRSeg1'].dropna()))
print(np.mean(clifford_firstWeek['HRSeg2A'].dropna()), np.mean(clifford_lastWeek['HRSeg2A'].dropna()))
print(np.mean(clifford_firstWeek['HRSeg2'].dropna()), np.mean(clifford_lastWeek['HRSeg2'].dropna()))
print(np.mean(clifford_firstWeek['HRSeg3'].dropna()), np.mean(clifford_lastWeek['HRSeg3'].dropna()))
print(np.mean(clifford_firstWeek['HRSeg4'].dropna()), np.mean(clifford_lastWeek['HRSeg4'].dropna()))
print(np.mean(clifford_firstWeek['FlowSeg1'].dropna()), np.mean(clifford_lastWeek['FlowSeg1'].dropna()))
print(np.mean(clifford_firstWeek['FlowSeg2A'].dropna()), np.mean(clifford_lastWeek['FlowSeg2A'].dropna()))
print(np.mean(clifford_firstWeek['FlowSeg2'].dropna()), np.mean(clifford_lastWeek['FlowSeg2'].dropna()))
print(np.mean(clifford_firstWeek['FlowSeg3'].dropna()), np.mean(clifford_lastWeek['FlowSeg3'].dropna()))
print(np.mean(clifford_firstWeek['FlowSeg4'].dropna()), np.mean(clifford_lastWeek['FlowSeg4'].dropna()))
# Out:
# Ttest_indResult(statistic=-4.7699613181495994, pvalue=4.0597399873488435e-06)
# Ttest_indResult(statistic=-4.9165132737954842, pvalue=2.3510210196706664e-06)
# Ttest_indResult(statistic=-4.0849936905725448, pvalue=7.1348691898533769e-05)
# Ttest_indResult(statistic=-10.231658196213026, pvalue=1.7478870800337187e-20)
# Ttest_indResult(statistic=-6.9293528970099869, pvalue=5.9137292897506283e-11)
# Ttest_indResult(statistic=-14.005829122780383, pvalue=1.0063251682293842e-32)
# Ttest_indResult(statistic=-13.126385071997213, pvalue=1.3083647555458329e-29)
# Ttest_indResult(statistic=-11.387967905688988, pvalue=4.838519595795689e-24)
# Ttest_indResult(statistic=-9.7559667389620763, pvalue=8.0426043454647404e-19)
# Ttest_indResult(statistic=-8.7690677833213844, pvalue=3.8504238201558064e-16)
# 122.47058823529412 132.27067669172934
# 122.70588235294117 132.90225563909775
# 122.82352941176471 131.6390977443609
# 134.11764705882354 155.90977443609023
# 132.0 152.39097744360902
# ...
